# %% [markdown]
# <a href="https://colab.research.google.com/github/christinaxliu/research/blob/main/JPL/DataFetcher/NASAExoplanetCatalogDataFetcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python script to fetch data from NASA Exoplanet Catalog (https://science.nasa.gov/exoplanets/exoplanet-catalog/) and parse html response to extract exoplant types.

# %%
import requests
import csv
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
exoplanet_types = [
    "Terrestrial",
    "Super+Earth",
    "Neptune-like",
    "Gas+Giant"
]

exoplanet_type_keys_dict ={
    "Terrestrial": "Terrestrial",
    "Super+Earth": "Super-Earth",
    "Neptune-like": "Neptune-Like",
    "Gas+Giant": "Gas-Giant"
}

exoplanet_type_num_pages_dict ={
    "Terrestrial": 14,
    "Super+Earth": 116,
    "Neptune-like": 133,
    "Gas+Giant": 125
}

# Fetch webpage content with the URL specified by the url parameter
def fetch_webpage(url):
    webpage_content = ""
    response = requests.get(url)
    if response.status_code == 200:
        webpage_content = response.text
    else:
        print(f"Failed to fetch the webpage with url: {url}, error code: {response.status_code}")
    return webpage_content

# Replace matched substring that matches the string specified by pattern_to_match with target_str
def replace_matched_str(input_str, pattern_to_match, target_str):
    result_str = input_str
    index = input_str.find(pattern_to_match)
    if index != -1:
        result_str = input_str[:index] + target_str + input_str[(index + len(pattern_to_match) + 1):]
    return result_str

# Parse webpage content to extract exoplanet data
def parse_nasa_exoplanet_catalog_webpage(webpage_content):
    exoplanet_names = []
    content = webpage_content

    index = index = content.find("<div class=\"hds-content-item\"><a href=\"/exoplanet-catalog/")
    while index != -1:
        content = content[index:]

        index = content.find("title=\"")
        content = content[(index+len("title=\"")):]

        index = content.find("\">")
        exoplanet_name = replace_matched_str(content[:index], "&amp;#8217;", "'s")
        exoplanet_names.append(exoplanet_name)
        content = content[index:]

        index = content.find("<div class=\"hds-content-item\"><a href=\"/exoplanet-catalog/")
    return exoplanet_names

# Save data stored in dictionary into CSV file at the location specified by csv_file_name
def save_as_csv(data_dict, csv_file_name):
    # Open the CSV file with the file name specified by csv_file_name in write mode
    with open(csv_file_name, 'w', newline='') as file:
        # Create a CSV writer object
        writer = csv.writer(file)

        # Write the header - the keys of the dictionary
        writer.writerow(data_dict.keys())

        # Write the data rows - the values of the dictionary
        writer.writerows(zip(*data_dict.values()))

# %%
found_expolanet_names = []
found_expolanet_types = []
exoplanet_type_dict = {
    "pl_name": found_expolanet_names,
    "pl_type": found_expolanet_types
}

num_exoplanet_per_type_dict = {
    "Terrestrial": 0,
    "Super+Earth": 0,
    "Neptune-like": 0,
    "Gas+Giant": 0
}

total_num_exoplanets = 0

# Loop through exoplanet types and corresponding pages to fetch exoplanet data from NASA Exoplanet Catalog
for exoplanet_type in exoplanet_types:
    exoplanet_type_num_pages = exoplanet_type_num_pages_dict[exoplanet_type]
    print(f"Fetch {exoplanet_type} exoplanet data from NASA Exoplanet Catalog with {exoplanet_type_num_pages} pages...\n")
    for page_minus_one in range(exoplanet_type_num_pages):
        # Construct URL with the specific exoplanet type and the specific page number
        url = f"https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno={page_minus_one + 1}&planet_type={exoplanet_type}&content_list=true"
        print(f"Fetch {exoplanet_type} exoplanet data with URL: {url}")

        # Fetch webpage content with the specific URL
        webpage_content = fetch_webpage(url)

        # Parse the webpage content to extract out the exoplanets with types
        exoplanet_names = parse_nasa_exoplanet_catalog_webpage(webpage_content)

        num_exoplanet_per_type_dict[exoplanet_type] += len(exoplanet_names)
        total_num_exoplanets += len(exoplanet_names)
        print(f"Fetched {len(exoplanet_names)} exoplanets with type: {exoplanet_type}")

        # Populate fetched exoplanets into the exoplanet type dictionary
        for explanet_name in exoplanet_names:
            exoplanet_type_dict["pl_name"].append(explanet_name)
            exoplanet_type_dict["pl_type"].append(exoplanet_type_keys_dict[exoplanet_type])
    print(f"Done with fetching of {exoplanet_type} exoplanet data. {num_exoplanet_per_type_dict[exoplanet_type]} {exoplanet_type} exoplanets were fetched.\n")

print(f"Fetched {total_num_exoplanets} exoplanets from NASA Exoplanet Catalog completed.")
print("Breakdown of number of exoplanets per type:")
for exoplanet_type in exoplanet_types:
    print(f"Number of {exoplanet_type} exoplanets: {num_exoplanet_per_type_dict[exoplanet_type]}")

# Save the exoplanet type dictionary into CSV file
csv_file_name = '/content/drive/My Drive/Colab Notebooks/research/JPL-Caltech/DataFetcher/NasaCatalogExoplanetType_2025.01.04.csv'
save_as_csv(exoplanet_type_dict, csv_file_name)
print(f"Exoplanets with types are saved as CSV file: {csv_file_name}.")
# Out:
# Fetch Terrestrial exoplanet data from NASA Exoplanet Catalog with 14 pages...
#
# Fetch Terrestrial exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=1&planet_type=Terrestrial&content_list=true
# Fetched 15 exoplanets with type: Terrestrial
# Fetch Terrestrial exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=2&planet_type=Terrestrial&content_list=true
# Fetched 15 exoplanets with type: Terrestrial
# Fetch Terrestrial exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=3&planet_type=Terrestrial&content_list=true
# Fetched 15 exoplanets with type: Terrestrial
# Fetch Terrestrial exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=4&planet_type=Terrestrial&content_list=true
# Fetched 15 exoplanets with type: Terrestrial
# Fetch Terrestrial exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=5&planet_type=Terrestrial&content_list=true
# Fetched 15 exoplanets with type: Terrestrial
# Fetch Terrestrial exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=6&planet_type=Terrestrial&content_list=true
# Fetched 15 exoplanets with type: Terrestrial
# Fetch Terrestrial exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=7&planet_type=Terrestrial&content_list=true
# Fetched 15 exoplanets with type: Terrestrial
# Fetch Terrestrial exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=8&planet_type=Terrestrial&content_list=true
# Fetched 15 exoplanets with type: Terrestrial
# Fetch Terrestrial exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=9&planet_type=Terrestrial&content_list=true
# Fetched 15 exoplanets with type: Terrestrial
# Fetch Terrestrial exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=10&planet_type=Terrestrial&content_list=true
# Fetched 15 exoplanets with type: Terrestrial
# Fetch Terrestrial exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=11&planet_type=Terrestrial&content_list=true
# Fetched 15 exoplanets with type: Terrestrial
# Fetch Terrestrial exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=12&planet_type=Terrestrial&content_list=true
# Fetched 15 exoplanets with type: Terrestrial
# Fetch Terrestrial exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=13&planet_type=Terrestrial&content_list=true
# Fetched 15 exoplanets with type: Terrestrial
# Fetch Terrestrial exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=14&planet_type=Terrestrial&content_list=true
# Fetched 15 exoplanets with type: Terrestrial
# Done with fetching of Terrestrial exoplanet data. 210 Terrestrial exoplanets were fetched.
#
# Fetch Super+Earth exoplanet data from NASA Exoplanet Catalog with 116 pages...
#
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=1&planet_type=Super+Earth&content_list=true
# Fetched 14 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=2&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=3&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=4&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=5&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=6&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=7&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=8&planet_type=Super+Earth&content_list=true
# Fetched 14 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=9&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=10&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=11&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=12&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=13&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=14&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=15&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=16&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=17&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=18&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=19&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=20&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=21&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=22&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=23&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=24&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=25&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=26&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=27&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=28&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=29&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=30&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=31&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=32&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=33&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=34&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=35&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=36&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=37&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=38&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=39&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=40&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=41&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=42&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=43&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=44&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=45&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=46&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=47&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=48&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=49&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=50&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=51&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=52&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=53&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=54&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=55&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=56&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=57&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=58&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=59&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=60&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=61&planet_type=Super+Earth&content_list=true
# Fetched 14 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=62&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=63&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=64&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=65&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=66&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=67&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=68&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=69&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=70&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=71&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=72&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=73&planet_type=Super+Earth&content_list=true
# Fetched 14 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=74&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=75&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=76&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=77&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=78&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=79&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=80&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=81&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=82&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=83&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=84&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=85&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=86&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=87&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=88&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=89&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=90&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=91&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=92&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=93&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=94&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=95&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=96&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=97&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=98&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=99&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=100&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=101&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=102&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=103&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=104&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=105&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=106&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=107&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=108&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=109&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=110&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=111&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=112&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=113&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=114&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=115&planet_type=Super+Earth&content_list=true
# Fetched 15 exoplanets with type: Super+Earth
# Fetch Super+Earth exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=116&planet_type=Super+Earth&content_list=true
# Fetched 14 exoplanets with type: Super+Earth
# Done with fetching of Super+Earth exoplanet data. 1735 Super+Earth exoplanets were fetched.
#
# Fetch Neptune-like exoplanet data from NASA Exoplanet Catalog with 133 pages...
#
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=1&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=2&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=3&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=4&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=5&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=6&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=7&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=8&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=9&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=10&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=11&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=12&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=13&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=14&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=15&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=16&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=17&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=18&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=19&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=20&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=21&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=22&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=23&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=24&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=25&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=26&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=27&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=28&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=29&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=30&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=31&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=32&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=33&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=34&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=35&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=36&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=37&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=38&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=39&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=40&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=41&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=42&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=43&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=44&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=45&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=46&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=47&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=48&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=49&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=50&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=51&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=52&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=53&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=54&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=55&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=56&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=57&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=58&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=59&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=60&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=61&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=62&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=63&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=64&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=65&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=66&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=67&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=68&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=69&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=70&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=71&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=72&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=73&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=74&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=75&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=76&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=77&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=78&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=79&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=80&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=81&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=82&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=83&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=84&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=85&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=86&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=87&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=88&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=89&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=90&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=91&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=92&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=93&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=94&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=95&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=96&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=97&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=98&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=99&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=100&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=101&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=102&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=103&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=104&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=105&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=106&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=107&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=108&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=109&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=110&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=111&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# Fetch Neptune-like exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=112&planet_type=Neptune-like&content_list=true
# Fetched 15 exoplanets with type: Neptune-like
# ...
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=45&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=46&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=47&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=48&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=49&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=50&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=51&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=52&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=53&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=54&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=55&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=56&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=57&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=58&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=59&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=60&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=61&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=62&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=63&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=64&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=65&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=66&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=67&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=68&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=69&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=70&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=71&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=72&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=73&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=74&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=75&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=76&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=77&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=78&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=79&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=80&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=81&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=82&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=83&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=84&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=85&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=86&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=87&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=88&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=89&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=90&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=91&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=92&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=93&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=94&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=95&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=96&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=97&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=98&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=99&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=100&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=101&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=102&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=103&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=104&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=105&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=106&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=107&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=108&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=109&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=110&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=111&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=112&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=113&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=114&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=115&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=116&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=117&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=118&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=119&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=120&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=121&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=122&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=123&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=124&planet_type=Gas+Giant&content_list=true
# Fetched 15 exoplanets with type: Gas+Giant
# Fetch Gas+Giant exoplanet data with URL: https://science.nasa.gov/exoplanets/exoplanet-catalog/?pageno=125&planet_type=Gas+Giant&content_list=true
# Fetched 8 exoplanets with type: Gas+Giant
# Done with fetching of Gas+Giant exoplanet data. 1868 Gas+Giant exoplanets were fetched.
#
# Fetched 5800 exoplanets from NASA Exoplanet Catalog completed.
# Breakdown of number of exoplanets per type:
# Number of Terrestrial exoplanets: 210
# Number of Super+Earth exoplanets: 1735
# Number of Neptune-like exoplanets: 1987
# Number of Gas+Giant exoplanets: 1868
# Exoplanets with types are saved as CSV file: /content/drive/My Drive/Colab Notebooks/research/JPL-Caltech/DataFetcher/NasaCatalogExoplanetType_2025.01.04.csv.
